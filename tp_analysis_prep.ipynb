# %% [markdown]
# Reads files from Google Drive...

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# %cd 'drive/MyDrive/Colab Notebooks/tagpro_analysis'
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/tagpro_analysis
# events/   __pycache__/  tp_analysis_prep.ipynb  tp_raw_event_reader.py
# matches/  scoreboards/  tp_analysis.py          tp_scoreboard_analysis.ipynb

# %% [markdown]
# # Tagpro analyses: Reading in match information

# %% [markdown]
# To start, we need to read in some files that help us process the data files from the [Tagpro science page](https://tagpro.eu/?science).

# %%
# %pip install ijson
import tp_raw_event_reader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from importlib import reload

reload(tp_raw_event_reader)
# Out:
# <module 'tp_raw_event_reader' from '/content/drive/MyDrive/Colab Notebooks/tagpro_analysis/tp_raw_event_reader.py'>

# %% [markdown]
# The following call will read matches in `matches_json_file` and save the scoreboards to Google Drive.
#
# to avoid requiring more RAM than we are alotted, we are going to stream in the matches from the .json file to avoid saving the entire file in memory while we are constructing the dataframe. The entire dataframe will be saved once all scoreboards are read into memory.

# %%
match_file = 'matches/bulkmatches2820001-3070000.json'
_, _ = tp_raw_event_reader.stream_matches(matches_json_file = match_file,
                                          match_range = None,
                                          retain_only_scoreboards = True,
                                          save_match_flag = False,
                                          save_bulk_flag = True,
                                          report_flag = True,
                                          report_every = 1000)
# Out:
# Streaming in match 2821000
# Streaming in match 2822000
# Streaming in match 2823000
# Streaming in match 2824000
# Streaming in match 2825000
# Streaming in match 2826000
# Streaming in match 2827000
# Streaming in match 2828000
# Streaming in match 2829000
# Streaming in match 2830000
# Streaming in match 2831000
# Streaming in match 2832000
# Streaming in match 2833000
# Streaming in match 2834000
# Streaming in match 2835000
# Streaming in match 2836000
# Streaming in match 2837000
# Streaming in match 2838000
# Streaming in match 2839000
# Streaming in match 2840000
# Streaming in match 2841000
# Streaming in match 2842000
# Streaming in match 2843000
# Streaming in match 2844000
# Streaming in match 2845000
# Streaming in match 2846000
# Streaming in match 2847000
# Streaming in match 2848000
# Streaming in match 2849000
# Streaming in match 2850000
# Streaming in match 2851000
# Streaming in match 2852000
# Streaming in match 2853000
# Streaming in match 2854000
# ...
